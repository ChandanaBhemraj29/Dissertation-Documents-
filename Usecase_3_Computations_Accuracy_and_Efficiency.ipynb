# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandanaBhemraj29/Dissertation-Documents-/blob/main/Usecase_3_Computations_Accuracy_and_Efficiency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

# Function to measure execution time
def measure_response_time(func, *args, **kwargs):
    # Record start time
    start_time = time.time()

    # Run the function
    result = func(*args, **kwargs)

    # Record end time
    end_time = time.time()

    # Calculate total execution time
    execution_time = end_time - start_time

    # Display the execution time
    print(f"Response time: {execution_time:.6f} seconds")

    return result

# Example of a function to test
def example_function(n):
    total = 0
    for i in range(n):
        total += i
    return total
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load the dataset
file_path = '/content/MPs-elected.xlsx'
data = pd.read_excel(file_path)
# Set up the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Clean the data
# Rename columns for clarity and drop unnecessary rows
cleaned_data = data.iloc[3:, :4]
cleaned_data.columns = ['Party', 'Female', 'Male', 'Total']
cleaned_data = cleaned_data.dropna()

# Convert 'Female', 'Male', and 'Total' to numeric values for plotting
cleaned_data['Female'] = pd.to_numeric(cleaned_data['Female'], errors='coerce')
cleaned_data['Male'] = pd.to_numeric(cleaned_data['Male'], errors='coerce')
cleaned_data['Total'] = pd.to_numeric(cleaned_data['Total'], errors='coerce')

# Calculate percentage of female MPs per party
cleaned_data['Female Percentage'] = (cleaned_data['Female'] / cleaned_data['Total']) * 100

# Show the cleaned data
cleaned_data.head()


# Bar chart data
parties = cleaned_data['Party']
female_counts = cleaned_data['Female']
male_counts = cleaned_data['Male']
female_percentage = cleaned_data['Female Percentage']

# Create stacked bar chart for gender balance
ax1.bar(parties, female_counts, label='Female MPs', color='lightcoral')
ax1.bar(parties, male_counts, bottom=female_counts, label='Male MPs', color='lightblue')

# Labels and titles for the first axis
ax1.set_xlabel('Political Parties')
ax1.set_ylabel('Number of MPs')
ax1.set_title('Gender Balance of MPs by Political Party (UK 2024)')
ax1.tick_params(axis='x', rotation=45)

# Add a secondary axis for percentage of female MPs
ax2 = ax1.twinx()
ax2.plot(parties, female_percentage, color='green', marker='o', label='Percentage of Female MPs', linestyle='--')
ax2.set_ylabel('Percentage of Female MPs')

# Add legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Display the plot
plt.tight_layout()
plt.show()



# Measure the response time of the example function
measure_response_time(example_function, 1000000)
# Out:
# Response time: 0.092315 seconds
# 499999500000

# %%
import time

# Function to measure execution time
def measure_response_time(func, *args, **kwargs):
    # Record start time
    start_time = time.time()

    # Run the function
    result = func(*args, **kwargs)

    # Record end time
    end_time = time.time()

    # Calculate total execution time
    execution_time = end_time - start_time

    # Display the execution time
    print(f"Response time: {execution_time:.6f} seconds")

    return result

# Example of a function to test
def example_function(n):
    total = 0
    for i in range(n):
        total += i
    return total


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the Excel file
file_path = '/content/MPs-elected.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')

# Count MPs by party and gender
party_gender_counts = df.groupby(['party_name', 'gender']).size().unstack(fill_value=0)

# Calculate percentage of female candidates for each party
total_candidates = party_gender_counts.sum(axis=1)
female_percentage = (party_gender_counts['Female'] / total_candidates) * 100

# Sort parties by total number of MPs (descending)
party_gender_counts = party_gender_counts.sort_values(by='Male', ascending=False)

# Create a stacked bar chart with a secondary axis for percentage of female candidates
fig, ax1 = plt.subplots(figsize=(12, 8))

# Plot the stacked bar chart
party_gender_counts.plot(kind='bar', stacked=True, ax=ax1, color=['#1f77b4', '#ff7f0e'])

# Set labels and title
ax1.set_xlabel('Political Party')
ax1.set_ylabel('Number of MPs')
ax1.set_title('Gender Balance of MPs by Political Party (2024 UK Elections)')

# Create a secondary axis for the percentage of female candidates
ax2 = ax1.twinx()
ax2.plot(female_percentage.index, female_percentage.values, color='green', marker='o', linestyle='-', linewidth=2, label='Percentage of Female Candidates')
ax2.set_ylabel('Percentage of Female Candidates')
ax2.set_ylim(0, 100)

# Add legends
ax1.legend(['Male', 'Female'], loc='upper left')
ax2.legend(loc='upper right')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Measure the response time of the example function
measure_response_time(example_function, 1000000)
# Out:
# Response time: 0.099303 seconds
# 499999500000

# %%
import time

# Function to measure execution time
def measure_response_time(func, *args, **kwargs):
    # Record start time
    start_time = time.time()

    # Run the function
    result = func(*args, **kwargs)

    # Record end time
    end_time = time.time()

    # Calculate total execution time
    execution_time = end_time - start_time

    # Display the execution time
    print(f"Response time: {execution_time:.6f} seconds")

    return result

# Example of a function to test
def example_function(n):
    total = 0
    for i in range(n):
        total += i
    return total


import pandas as pd
import matplotlib.pyplot as plt

# Load data from the Excel file using pd.read_excel
# Replace 'your_file.xlsx' with the path to your actual file
df = pd.read_excel('/content/MPs-elected.xlsx')


# Group the data by party abbreviation and gender
gender_party_count = df.groupby(['party_abbreviation', 'gender']).size().unstack(fill_value=0)

# Plot the data as a grouped bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Create an array for positioning
x = np.arange(len(gender_party_count.index))  # The label locations
width = 0.35  # The width of the bars

# Plotting both male and female bars side by side
bars_male = ax.bar(x - width/2, gender_party_count['Male'], width, label='Male', color='skyblue')
bars_female = ax.bar(x + width/2, gender_party_count['Female'], width, label='Female', color='lightcoral')

# Add labels, title, and custom ticks for readability
ax.set_xlabel('Party')
ax.set_ylabel('Number of Candidates')
ax.set_title('Number of Male and Female Candidates per Party')
ax.set_xticks(x)
ax.set_xticklabels(gender_party_count.index)
ax.legend()

# Add number labels on top of each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # Offset the text by 3 points above the bar
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(bars_male)
add_labels(bars_female)

# Adjust layout for better readability
plt.tight_layout()

# Show the plot
plt.show()

# Measure the response time of the example function
measure_response_time(example_function, 1000000)
# Out:
# Response time: 0.145752 seconds
# 499999500000
